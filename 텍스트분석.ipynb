# %%
import requests

# %%
url = "https://finance.naver.com/item/main.nhn?code=005930"

# %%
resp = requests.get(url) #함수 호출. return 값을 받는다.

# %%
resp
# Out:
# <Response [200]>

# %%
resp.text
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\t\n\t\n\t\n\t\n<html lang=\'ko\'>\n<head>\n\n\n\t\n\t\t<title>삼성전자 : 네이버 금융</title>\n\t\n\t\n\n\n\n\n\n\t\n\t\n\t\t<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n\t\n\n\n<meta http-equiv="Content-Script-Type" content="text/javascript">\n<meta http-equiv="Content-Style-Type" content="text/css">\n\n\n\n\t\n    \n        <meta property="og:url" content="https://finance.naver.com/item/main.nhn?code=005930"/>\n        \n\t\t\t\n\t\t    \n\t\t    \t<meta property="og:title" content="삼성전자 - 네이버 금융 : 네이버 금융"/>\n\t\t     \n\t\t\n\t\t\n\t\t\t\n\t\t\t   <meta property="og:description" content="관심종목의 실시간 주가를 가장 빠르게 확인하는 곳"/>\n\t\t    \n\t\t    \n\t\t\n\t\t \n\t\t\t\n\t\t\t    <meta property="og:image" content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png"/>\n\t\t    \n\t\t    \n\t\t\n    \n\n<meta property="og:type" content="article"/>\n<meta property="og:article:thumbnailUrl" content=""/>\n<meta property="og:article:author" c
# ...

# %%
resp.status_code
# Out:
# 200

# %%
html = resp.text

# %%
type(html)
# Out:
# str

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html, "html5lib")

# %%
tags = soup.select("#_per")

# %%
tags[0]
# Out:
# <em id="_per">17.07</em>

# %%
tags[0].text
# Out:
# '17.07'

# %%
import requests
from bs4 import BeautifulSoup

# get
resp = requests.get("https://finance.naver.com/item/main.nhn?code=005490")
html = resp.text

#create instance (parsing)
soup = BeautifulSoup(html, "html5lib")
tags = soup.select("#_per")
tag = tags[0]
print(tag.text)
# Out:
# 10.63

# %%
a = 'hello'
type(a)
# Out:
# str

# %%
a.upper()
# Out:
# 'HELLO'

# %%
import requests
from bs4 import BeautifulSoup

url = "https://news.naver.com/"
resp = requests.get(url)
html = resp.text

soup = BeautifulSoup(html, "html5lib")
tags = soup.select("#today_main_news > div.hdline_news > ul > li > div.hdline_article_tit > a")
#마우스 우클릭>inspect>가지고 오고 싶은 부분 마우스 우클릭>copy>copy selector
#nth-child를 지원안하는 경우에는 nth-of-type을 써준다.
for tag in tags:
    print(tag.text.strip())
# Out:
# 제주항공 붙잡는 이스타… 일부 직원들, “체불 임금 포기할테니 인수해달라”
# 채널A 수사팀은 "실체 규명 안됐다"는데 법무부는 "상당한 정도 수사 진행"
# 아시아나 인수 해외 결합심사 마무리…현산 이제 속도낼까
# 홍영표, 전대 불출마 선언…당권경쟁 3파전으로(종합)
# 윤석열, 종일 검사장 회의…중앙지검장에 "안오는게 좋겠다"(종합)

# %%
import requests
from bs4 import BeautifulSoup

url = "https://movie.naver.com/movie/bi/mi/review.nhn?code=189537"
resp = requests.get(url)
html = resp.text

soup = BeautifulSoup(html, "html5lib")
tags = soup.select("#reviewTab > div > div > ul > li > a > strong")
#마우스 우클릭>inspect>가지고 오고 싶은 부분 마우스 우클릭>copy>copy selector
#nth-child를 지원안하는 경우에는 nth-of-type을 써준다.
for tag in tags:
    print(tag.text.strip())
# Out:
# 영화 살아있다 후기, 시작은 좋았는데 결말이..
# 포스트 좀비물을 꿈꾸었지만 <#살아있다>
# <#살아있다>후기 및 분석-겉멋만들고 일시적으로 소모되는 장치들(스포일러 있음)
# [개봉예정] #살아있다 (#ALIVE, 2020)
# 후반부만 빼면 상당히 볼만했던 #살아있다. (스포주의)
# #Alive, #살아있다
# [예매권]<#살아있다> 내 식욕이 살아났다.
# 영화리뷰/스릴러/좀비물/#살아있다./유아인/박신혜
# <#살아야한다> 한국의 보편적인 공간에서 펼쳐지는 보편적인 좀비영화
# 마스크 쓰고 본 #살아있다 (유아인, 박신혜 주연)

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome('/home/piai/chromedriver')

# %%
driver.get("https://www.naver.com/")

# %%
selector = "#NM_FAVORITE > div.group_nav > ul.list_nav.NM_FAVORITE_LIST > li:nth-child(1) > a"
ui = driver.find_element_by_css_selector(selector)
ui.click() #사이트로 이동함.

# %%
driver.find_element_by_css_selector("#query").send_keys("포스코")

# %%
from selenium.webdriver.common.keys import Keys
css_selector = "#query"

# %%
elem = driver.find_element_by_css_selector(css_selector)
elem.send_keys("코로나")
elem.send_keys(Keys.RETURN)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-74-a957b2b6093b> in <module>
# ----> 1 elem = driver.find_element_by_css_selector(css_selector)
#       2 elem.send_keys("코로나")
#       3 elem.send_keys(Keys.RETURN)
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_css_selector(self, css_selector)
#     596             element = driver.find_element_by_css_selector('#foo')
#     597         """
# --> 598         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     599
#     600     def find_elements_by_css_selector(self, css_selector):
#
# ~/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
# ...

# %%
#네이버 영화 평점 상단 5개 프린트 (1-5페이지) : for문 이용

# %%
import requests
import pprint

def kor2eng(kor):del result['2011년 이전']
del result['2012년']
del result['2013년']
del result['2014년']
del result['2015년']
del result['2016년']
del result['2017년']
del result['2018년']
result.head()
    url = "https://translate.kakao.com/translator/translate.json"
    
    headers = {
        "Referer":"https://translate.kakao.com", #Origin
        "User-Agent":"Mozilla/5.0"
    
    }
    
    data = {
        "queryLanguage": "kr",
        "resultLanguage": "en",
        "q": kor
    }
    
    resp = requests.post(url, headers=headers, data=data) #POST 방식
    data = resp.json()
    output=data['result']['output'][0][0]
    print(output)

# %%
kor2eng("자고 싶다")
# Out:
# I want to sleep
